# %% [markdown]
# # GMM Project

# %% [markdown]
# ### Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
# Loading the data
df = pd.read_csv('../data/Bus77_Load.csv')
df.head()
# Out:
#    Load(MW)
# 0    0.7283
# 1    1.3353
# 2    4.3548
# 3    1.6287
# 4    3.9702

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Load(MW)    0
# dtype: int64

# %%
# Boxplot of the load
plt.figure(figsize=(6, 3))
plt.boxplot(df['Load(MW)'], vert=False)
plt.title('Boxplot of Load')
plt.xlabel('Load (MW)')
plt.grid(axis='x', alpha=0.75)
plt.savefig('../results/Bus77_Load_Boxplot.png', dpi=300)
plt.show()

# The box plot shows there might be some outliers in the data. Let us chekk the histogram to see the distribution of the load.

# Histogram of the load
data = df['Load(MW)'].values

# Define bin edges with interval width = 0.125
bin_edges = np.arange(start=np.floor(min(data)), 
                      stop=np.ceil(max(data)) + 0.125, 
                      step=0.125)

# Plot histogram as a PDF
plt.hist(data, bins=bin_edges, density=True, color='blue', alpha=0.6, edgecolor='black')
plt.xlabel("Load (MW)")
plt.ylabel("Density")
plt.title("PDF Histogram of Load (bin width = 1/8 MW)")
plt.grid(True)
plt.show()


# The histogram shows that there are three peaks in the data. This is an indication that the data might be multimodal. Let us check the distribution of the load using a kernel density estimate (KDE) plot.

# KDE plot of the load
plt.figure(figsize=(6, 3))
sns.kdeplot(df['Load(MW)'], color='red', fill=True, alpha=0.7)
plt.hist(df['Load(MW)'], bins=50, density=True, color='blue', alpha=0.7)
plt.title('KDE Plot of Load')
plt.xlabel('Load (MW)')
plt.ylabel('Density')
plt.grid(axis='y', alpha=0.75)
plt.savefig('../results/Bus77_Load_KDE.png', dpi=300)
plt.show()

# The KDE plot shows that the data is multimodal. This is an indication that the data might be generated from a mixture of distributions.

# %% [markdown]
# ### Choice of optimal K
# #### K-means

# %% [markdown]
# Let:
#
# - $X = \{x_1, x_2, \dots, x_N\} $ be your dataset
# - $ C_k $ be the set of data points assigned to cluster $ k $
# - $ \mu_k $ be the centroid (mean) of cluster $ C_k $
# - $ K $ be the number of clusters
#
# Then, the **inertia** is computed as:
#
#
# $ Inertia = \sum_{k=1}^{K} \sum_{x_i \in C_k} \| x_i - \mu_k \|^2$
#
#
# This is the sum of **squared Euclidean distances** between each point and the centroid of its assigned cluster for all $ K $ clusters.

# %%
from sklearn.cluster import KMeans

data = df['Load(MW)'].values.reshape(-1, 1)

kmeans_inertia = []

# Try values of K from 1 to 7
ks = list(range(1, 8))

for k in ks:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
    kmeans.fit(data)
    kmeans_inertia.append(kmeans.inertia_)  # sum of squared distances to cluster centers

# Plot K-means Elbow
plt.figure(figsize=(6, 4))
plt.plot(ks, kmeans_inertia, marker='o', color='green')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia (Within-Cluster Sum of Squares)")
plt.title("K-means Elbow Method")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Bayesian Information Criterion
#
# The Bayesian Information Criterion (BIC) is given by:
#
# $$
# \text{BIC} = -2 \cdot \log L + p \cdot \log N
# $$
#
# Where:
#
# - $ \log L $ = log-likelihood of the model
# - $ p $ = number of free parameters in the GMM
# - $ N $ = number of data points

# %%
from sklearn.mixture import GaussianMixture

log_likelihoods = []
bics = []

n = len(data)
complexity_penalty = []

for k in ks:
    gmm = GaussianMixture(n_components=k, random_state=42)
    gmm.fit(data)
    
    log_likelihood = gmm.score(data) * n
    p = gmm._n_parameters()  # number of free parameters
    penalty = p * np.log(n)
    
    log_likelihoods.append(log_likelihood)
    bics.append(-2 * log_likelihood + penalty)
    complexity_penalty.append(penalty)


plt.figure(figsize=(15, 4))

# Log-Likelihood
plt.subplot(1, 3, 1)
plt.plot(ks, log_likelihoods, marker='o')
plt.xticks(ks)
plt.xlabel("Number of Components (K)")
plt.ylabel("Log-Likelihood")
plt.title("Model Fit: Log-Likelihood")
plt.grid(True)

# Complexity penalty
plt.subplot(1, 3, 2)
plt.plot(ks, complexity_penalty, marker='o', color='orange')
plt.xticks(ks)
plt.xlabel("Number of Components (K)")
plt.ylabel("Complexity Penalty (p × log N)")
plt.title("Model Complexity Penalty")
plt.grid(True)

# BIC
plt.subplot(1, 3, 3)
plt.plot(ks, bics, marker='o', color='red')
plt.xticks(ks)
plt.xlabel("Number of Components (K)")
plt.ylabel("BIC")
plt.title("Model Selection via BIC")
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fitting Base GMM Model

# %%
from sklearn.mixture import GaussianMixture
import time
from sklearn.cluster import KMeans
from scipy.stats import norm

# Prepare data
data_shaped = df['Load(MW)'].values.reshape(-1, 1)
n_samples = len(data_shaped)
K = 3

# Extractinng initial estimates for the parameters

# K-means initialization for initial guess
kmeans_init = KMeans(n_clusters=K, random_state=42, n_init=5)
cluster_labels_init = kmeans_init.fit_predict(data_shaped)

initial_weights = []
initial_means = []
initial_variances = []

for k in range(K):
    cluster_points = data_shaped[cluster_labels_init == k]
    N_k = len(cluster_points)
    initial_weights.append(N_k / len(data_shaped))
    initial_means.append(np.mean(cluster_points))
    initial_variances.append(np.var(cluster_points))


# Fit GMM with K = 3
gmm = GaussianMixture(n_components=K, random_state=42, n_init=1, init_params='kmeans')
# time counter
start_time = time.perf_counter()
gmm.fit(data_shaped)
end_time = time.perf_counter()

elapsed_time = end_time - start_time
print(f"Time taken to fit GMM with K = {K}: {elapsed_time:.4f} seconds")

# Number of iterations
n_iteration = gmm.n_iter_ 

# Get learned parameters
weights = gmm.weights_
means = gmm.means_.flatten()
variances = gmm.covariances_.flatten()
stds = np.sqrt(variances)
# Out:
# Time taken to fit GMM with K = 3: 0.0321 seconds

# %%
# Plotting

from matplotlib.gridspec import GridSpec

# Set up layout: 2 rows, 2 columns
fig = plt.figure(figsize=(12, 5))
gs = GridSpec(3, 2, width_ratios=[2.5, 1.5], height_ratios=[2.5, 2.5, 1])

# --- LEFT: PDF Histogram and GMM Clusters ---
ax0 = fig.add_subplot(gs[:, 0])  # span both rows
bin_edges = np.arange(start=np.floor(min(data_shaped)), 
                      stop=np.ceil(max(data_shaped)) + 0.125, 
                      step=0.125)
ax0.hist(data_shaped.flatten(), bins=bin_edges, density=True, alpha=0.5, edgecolor='black', label='Data Histogram')

x = np.linspace(min(data_shaped), max(data_shaped), 1000)
colors = ['orange', 'green', 'red']

for i in range(K):
    pdf = weights[i] * norm.pdf(x, means[i], stds[i])
    ax0.plot(x, pdf, label=f'Cluster {i+1}', color=colors[i])

ax0.set_xlabel("Load (MW)")
ax0.set_ylabel("Density")
ax0.set_title(f"Standard GMM PDF Fit with K = {K}")
ax0.legend()
ax0.grid(True)

# Set up right side for two stacked tables
ax1 = fig.add_subplot(gs[0, 1])
ax1.axis('off')

# ---- Initial Parameters Table ----
initial_table_data = [["Cluster", "Weight (π)", "Mean (μ)", "Variance (σ²)"]]
for i in range(K):
    row = [f"{i+1}",
           f"{initial_weights[i]:.4f}",
           f"{initial_means[i]:.4f}",
           f"{initial_variances[i]:.4f}"]
    initial_table_data.append(row)

# Title
ax1.text(0.5, 1.1, "Initial Parameter Estimates (K-means)",
         fontsize=11, ha='center', va = 'top', fontweight='bold')

# Draw initial table
table1 = ax1.table(cellText=initial_table_data, loc='center', cellLoc='center')
table1.auto_set_font_size(False)
table1.set_fontsize(10)
table1.scale(1.2, 1.5)

# ---- Final Parameters Table (New axis below) ----
ax1b = fig.add_subplot(gs[1, 1])
ax1b.axis('off')

final_table_data = [["Cluster", "Weight (π)", "Mean (μ)", "Variance (σ²)"]]
for i in range(K):
    row = [f"{i+1}",
           f"{weights[i]:.4f}",
           f"{means[i]:.4f}",
           f"{variances[i]:.4f}"]
    final_table_data.append(row)

# Title
ax1b.text(0.5, 1.1, "Final GMM Parameters (After EM)",
          fontsize=11, ha='center',  va = 'top', fontweight='bold')

# Draw final table
table2 = ax1b.table(cellText=final_table_data, loc='center', cellLoc='center')
table2.auto_set_font_size(False)
table2.set_fontsize(10)
table2.scale(1.2, 1.5)

#Runtime Text
ax2 = fig.add_subplot(gs[2, 1])
ax2.axis('off')
ax2.text(0.5, 0.5, f"Time taken to fit GMM: {elapsed_time:.4f} seconds",
         ha='center', va='center', fontsize=11, fontweight='bold')
ax2.text(0.5, 0.1, f"EM Iterations: {n_iteration}", ha='center',  fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig("../results/standard_gmm_fit_with_table.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Improved GMM

# %% [markdown]
# - Faster EM

# %%
from sklearn.mixture import GaussianMixture
import time

# Config: Lower precision, early stop, fewer iterations
gmm_fast_em = GaussianMixture(
    n_components=K,
    max_iter=30,          # fewer iterations
    tol=1e-2,             # early stopping tolerance
    n_init=1,             # single initialization
    init_params='kmeans', # K-means initialization
    random_state=42
)

start_time = time.perf_counter()
gmm_fast_em.fit(data_shaped)
end_time = time.perf_counter()

# Calculate elapsed time

elapsed_time_fast_em = end_time - start_time

# No of iterations
n_iteration_fast_em = gmm_fast_em.n_iter_ 

weights_fast_em = gmm_fast_em.weights_
means_fast_em = gmm_fast_em.means_.flatten()
variances_fast_em = gmm_fast_em.covariances_.flatten()
stds_fast_em = np.sqrt(variances_fast_em)


print(f"GMM with fast EM completed in {elapsed_time_fast_em:.4f} seconds.")
# Out:
# GMM with fast EM completed in 0.0322 seconds.

# %%
# Plotting

from matplotlib.gridspec import GridSpec

# Set up layout: 2 rows, 2 columns
fig = plt.figure(figsize=(12, 5))
gs = GridSpec(3, 2, width_ratios=[2.5, 1.5], height_ratios=[2.5, 2.5, 1])

# --- LEFT: PDF Histogram and GMM Clusters ---
ax0 = fig.add_subplot(gs[:, 0])  # span both rows
bin_edges = np.arange(start=np.floor(min(data_shaped)), 
                      stop=np.ceil(max(data_shaped)) + 0.125, 
                      step=0.125)
ax0.hist(data_shaped.flatten(), bins=bin_edges, density=True, alpha=0.5, edgecolor='black', label='Data Histogram')

x = np.linspace(min(data_shaped), max(data_shaped), 1000)
colors = ['orange', 'green', 'red']

for i in range(K):
    pdf = weights_fast_em[i] * norm.pdf(x, means_fast_em[i], stds_fast_em[i])
    ax0.plot(x, pdf, label=f'Cluster {i+1}', color=colors[i])

ax0.set_xlabel("Load (MW)")
ax0.set_ylabel("Density")
ax0.set_title(f"GMM (with Fast EM) PDF Fit with K = {K}")
ax0.legend()
ax0.grid(True)

# Set up right side for two stacked tables
ax1 = fig.add_subplot(gs[0, 1])
ax1.axis('off')

# ---- Initial Parameters Table ----
initial_table_data = [["Cluster", "Weight (π)", "Mean (μ)", "Variance (σ²)"]]
for i in range(K):
    row = [f"{i+1}",
           f"{initial_weights[i]:.4f}",
           f"{initial_means[i]:.4f}",
           f"{initial_variances[i]:.4f}"]
    initial_table_data.append(row)

# Title
ax1.text(0.5, 1.1, "Initial Parameter Estimates (K-means)",
         fontsize=11, ha='center', va = 'top', fontweight='bold')

# Draw initial table
table1 = ax1.table(cellText=initial_table_data, loc='center', cellLoc='center')
table1.auto_set_font_size(False)
table1.set_fontsize(10)
table1.scale(1.2, 1.5)

# ---- Final Parameters Table (New axis below) ----
ax1b = fig.add_subplot(gs[1, 1])
ax1b.axis('off')

final_table_data = [["Cluster", "Weight (π)", "Mean (μ)", "Variance (σ²)"]]
for i in range(K):
    row = [f"{i+1}",
           f"{weights_fast_em[i]:.4f}",
           f"{means_fast_em[i]:.4f}",
           f"{variances_fast_em[i]:.4f}"]
    final_table_data.append(row)

# Title
ax1b.text(0.5, 1.1, "Final GMM Parameters (After EM)",
          fontsize=11, ha='center',  va = 'top', fontweight='bold')

# Draw final table
table2 = ax1b.table(cellText=final_table_data, loc='center', cellLoc='center')
table2.auto_set_font_size(False)
table2.set_fontsize(10)
table2.scale(1.2, 1.5)

#Runtime Text
ax2 = fig.add_subplot(gs[2, 1])
ax2.axis('off')
ax2.text(0.5, 0.5, f"Time taken to fit GMM (fast EM): {elapsed_time_fast_em:.4f} seconds",
         ha='center', va='center', fontsize=11, fontweight='bold')
ax2.text(0.5, 0.1, f"EM Iterations: {n_iteration_fast_em}", ha='center',  fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig("../results/fast_em_gmm_fit_with_table.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Non-iterative GMM

# %%
import numpy as np
import time
from sklearn.cluster import KMeans
from scipy.stats import norm
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# --- Initialize lists for parameters ---
weights_gmm_non_iterative = []
means_gmm_non_iterative = []
variances_gmm_non_iterative = []


# --- Start timer ---
start_time = time.perf_counter()

# --- Run K-means ---
kmeans = KMeans(n_clusters=K, n_init=1, random_state=42)

cluster_labels = kmeans.fit_predict(data_shaped)

# --- Calculate parameters ---
for k in range(K):
    cluster_points = data_shaped[cluster_labels == k]
    N_k = len(cluster_points)

    weights_gmm_non_iterative.append(N_k / len(data_shaped))
    means_gmm_non_iterative.append(np.mean(cluster_points))
    variances_gmm_non_iterative.append(np.var(cluster_points))  # ddof=0
# --- Stop timer ---
elapsed_time = time.perf_counter() - start_time



# --- Convert to arrays ---
weights_gmm_non_iterative = np.array(weights_gmm_non_iterative)
means_gmm_non_iterative = np.array(means_gmm_non_iterative)
variances_gmm_non_iterative = np.array(variances_gmm_non_iterative)
stds_gmm_non_iterative = np.sqrt(variances_gmm_non_iterative)

# %%
# Set up plot layout
fig = plt.figure(figsize=(12, 5))
gs = GridSpec(2, 2, width_ratios=[2.5, 1.5], height_ratios=[5, 1])

# --- LEFT: Histogram + PDFs ---
ax0 = fig.add_subplot(gs[:, 0])
bin_edges = np.arange(start=np.floor(min(data_shaped)),
                      stop=np.ceil(max(data_shaped)) + 0.125,
                      step=0.125)
ax0.hist(data_shaped.flatten(), bins=bin_edges, density=True, alpha=0.6,
         edgecolor='black', label='Data Histogram')

x = np.linspace(min(data_shaped), max(data_shaped), 1000)
colors = ['orange', 'green', 'red']

for i in range(K):
    pdf = weights_gmm_non_iterative[i] * norm.pdf(x, means_gmm_non_iterative[i], stds_gmm_non_iterative[i])
    ax0.plot(x, pdf, label=f"GMM Component {i+1}", color=colors[i])

ax0.set_title("Non-Iterative GMM Approximation")
ax0.set_xlabel("Load (MW)")
ax0.set_ylabel("Density")
ax0.legend()
ax0.grid(True)

# --- RIGHT: Parameter Table ---
ax1 = fig.add_subplot(gs[0, 1])
ax1.axis('off')

table_data = [["Cluster", "Weight (π)", "Mean (μ)", "Variance (σ²)"]]
for i in range(K):
    row = [f"{i+1}",
           f"{weights_gmm_non_iterative[i]:.4f}",
           f"{means_gmm_non_iterative[i]:.4f}",
           f"{variances_gmm_non_iterative[i]:.4f}"]
    table_data.append(row)

table = ax1.table(cellText=table_data, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)

# --- Runtime ---
ax2 = fig.add_subplot(gs[1, 1])
ax2.axis('off')
ax2.text(0.5, 0.5, f"Time taken: {elapsed_time:.4f} seconds",
         ha='center', va='center', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig("../results/gmm_non_iterative_fit_with_table.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import sys
sys.path.append('../src/')
from benchmark_gmm import benchmark_gmm
from benchmark_gmm_non_iterative import benchmark_gmm_non_iterative, compute_gmm_non_iterative


# Standard GMM
meantime_gmm, _ =  benchmark_gmm("Standard GMM", gmm, data_shaped)


# Fast EM GMM
meantime_gmm_fast_em, _ =  benchmark_gmm("Fast EM GMM", gmm_fast_em, data_shaped)

# Non-iterative GMM
meantime_gmm_non_iterative = benchmark_gmm_non_iterative(
    "GMM (Non-Iterative)",
    lambda X: compute_gmm_non_iterative(X, K=3),
    data_shaped
)
# Out:
# Standard GMM
# Median time over 10 runs: 0.039583 s
# Mean time: 0.058342 s ± 0.036705
# Average EM iterations: 3.00 ± 0.00
# Fast EM GMM
# Median time over 10 runs: 0.043693 s
# Mean time: 0.056793 s ± 0.034592
# Average EM iterations: 2.00 ± 0.00
# GMM (Non-Iterative)
# Median time over 10 runs: 0.004643 s
# Mean time: 0.013633 s ± 0.017496

# %% [markdown]
# ### RMSE Between Histogram and GMM PDF
#
# We compute the RMSE between the predicted PDF of the GMM and the actual data histogram.
#
# - Let $x_i$ be the center of the $i$-th histogram bin.
# - Let $\text{hist}(x_i)$ be the density of the histogram at $x_i$.
# - Let $\text{pdf}(x_i)$ be the predicted value from the GMM at $x_i$.
#
# Then the **Root Mean Squared Error (RMSE)** is:
#
# $$
# \text{RMSE} = \sqrt{ \frac{1}{N} \sum_{i=1}^{N} \left( \text{hist}(x_i) - \text{pdf}(x_i) \right)^2 }
# $$
#
# Where:
# - $N$ is the number of histogram bins.
# - A lower RMSE indicates the GMM PDF is more closely matching the histogram.
#
# This provides a numerical way to evaluate how well the model captures the shape of the data distribution.

# %%
import sys
sys.path.append('../src/')
from compute_rmse import compute_rmse


bin_edges = np.arange(start=np.floor(min(data_shaped)),
                      stop=np.ceil(max(data_shaped)) + 0.125,
                      step=0.125)

hist_vals, _ = np.histogram(data_shaped, bins=bin_edges, density=True)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

rmse_standard = compute_rmse(
    bin_centers, hist_vals,
    weights, means, stds
)

rmse_fast = compute_rmse(
    bin_centers, hist_vals,
    weights_fast_em, means_fast_em, stds_fast_em
)

rmse_non_iterative = compute_rmse(
    bin_centers, hist_vals,
    weights_gmm_non_iterative,
    means_gmm_non_iterative,
    stds_gmm_non_iterative
)


plt.bar(["Standard", "Fast EM", "Non-Iterative"],
        [rmse_standard, rmse_fast, rmse_non_iterative],
        color=["blue", "green", "orange"])
plt.ylabel("RMSE")
plt.title("RMSE between Histogram and GMM PDFs")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Model names
labels = ["Standard", "Fast EM", "Non-Iterative"]

# Values
rmse_vals = [rmse_standard, rmse_fast, rmse_non_iterative]
runtime_vals = [meantime_gmm, meantime_gmm_fast_em, meantime_gmm_non_iterative]

# Bar positions
x = np.arange(len(labels))  # [0, 1, 2]
width = 0.35  # Width of each bar

# Create figure and first axis (RMSE)
fig, ax1 = plt.subplots(figsize=(8, 5))

bars1 = ax1.bar(x - width/2, rmse_vals, width, label='RMSE', color='steelblue')
ax1.set_ylabel("RMSE", color='steelblue')
ax1.tick_params(axis='y', labelcolor='steelblue')
ax1.set_ylim(0, max(rmse_vals) * 1.2)

# Create second axis (Runtime)
ax2 = ax1.twinx()
bars2 = ax2.bar(x + width/2, runtime_vals, width, label='Mean Runtime (s)', color='orange')
ax2.set_ylabel("Mean Runtime (s)", color='orange')
ax2.tick_params(axis='y', labelcolor='orange')
ax2.set_ylim(0, max(runtime_vals) * 1.2)
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f"{y:.4f}"))

# X-axis and formatting
ax1.set_title("RMSE vs Mean Runtime for GMM Variants (10 Runs Each)")
ax1.set_xticks(x)
ax1.set_xticklabels(labels)
ax1.grid(axis='y', linestyle='--', alpha=0.6)

# Combine legends from both axes
bars = bars1 + bars2
labels_combined = [bar.get_label() for bar in bars]
#ax1.legend(bars, labels_combined, loc='upper right')

plt.tight_layout()
plt.savefig("../results/gmm_rmse_and_runtime_dual_axis.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Model names (excluding Standard for this plot)
labels = ["Fast EM", "Non-Iterative"]

# RMSE values (precomputed)
rmse_vals = [rmse_fast, rmse_non_iterative]
rmse_baseline = rmse_standard

# Runtime values (precomputed)
runtime_vals = [meantime_gmm_fast_em, meantime_gmm_non_iterative]
runtime_baseline = meantime_gmm

# Compute % change relative to standard
rmse_changes = [100 * (val - rmse_baseline) / rmse_baseline for val in rmse_vals]
runtime_changes = [100 * (val - runtime_baseline) / runtime_baseline for val in runtime_vals]

# Bar positions
x = np.arange(len(labels))
width = 0.35

# Plotting
fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(x - width/2, rmse_changes, width, label='Δ RMSE (%)', color='steelblue')
ax.bar(x + width/2, runtime_changes, width, label='Δ Runtime (%)', color='orange')

# Formatting
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.axhline(0, color='gray', linewidth=0.8)
ax.set_ylabel("Percentage Change from Standard GMM (%)")
ax.set_title("Relative Change in RMSE and Runtime vs Standard GMM")
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.savefig("../results/gmm_relative_change_fast_noniterative.png", dpi=300)
plt.show()
